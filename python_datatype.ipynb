# %%
# String Quiz

# %%
text = "  A tale that was not right  "
# 'a'가 출력
text[5]
#  'right'가 출력
text[-7:-2]
text.split(' ')[-3]
# 홀수번 인덱스 요소만 출력
text[0:30:2]
text[::2]
# 'tale'을 'story'로 변경
text.replace('tale', 'story')
# text을 역순으로 출력
text[::-1]
# 't'의 갯수를 출력'
text.count('t')
#  'that'이라는 단어가 text에 포함되어 있는지 확인
'that' in text
#  text의 길이를 출력
len(text)
# 위의 문장을 대문자로 변환하시오
text.upper()
# 위의 문장을 소문자로 변환하시오
text.lower()
# 위의 문장의 좌우공백을 제거하시오
text.strip()
# Out:
# 'A tale that was not right'

# %%
msg1 = '여러분'
msg2 = '파이팅!'

# msg1과 msg2를 활용하여 다음과 같이 출력되도록 하시오
# => '여러분, 파이팅!파이팅!파이팅! ~'
msg1 + ', ' + msg2*3 + ' ~'
# Out:
# '여러분, 파이팅!파이팅!파이팅! ~'

# %%
# 임의의 문장을 입력받은 후, "당신이 입력한 문장의 길이는 __ 입니다."라고 출력되도록 하시오..

text = input('문장을 입력하세요')
print("당신이 입력한 문장의 길이는 {}입니다.".format(len(text)))

text = input('문장을 입력하세요')
length_text = len(text)
print(f"당신이 입력한 문장의 길이는 {length_text}입니다.")
# Out:
# 문장을 입력하세요python is easy and fun
# 당신이 입력한 문장의 길이는 22입니다.
# 문장을 입력하세요python is easy and fun
# 당신이 입력한 문장의 길이는 22입니다.

# %%
# 임의의 문장을 입력받은 후, "당신이 입력한 문장은 "파이썬"이라는 단어를 포함하고 있습니다 or
# 포함하고 있지 않습니다."라고 출력되도록 하시오.

text = input('문장을 입력하세요')

if '파이썬' in text:
  print("당신이 입력한 문장은 '파이썬'이라는 단어를 포함하고 있습니다")
else:
  print("당신이 입력한 문장은 '파이썬'이라는 단어를 포함하고 있지 않습니다")
# Out:
# 문장을 입력하세요자바는 재미가 있어요
# 당신이 입력한 문장은 '파이썬'이라는 단어를 포함하고 있지 않습니다

# %%
# 임의의 사람에게 이름, 생년월일, 나이를 입력받은 후,
#  => " 당신의 이름은 ___이고, ___월 달 출생이고, ___살입니다" 라고 출력되도록 하시오
# 단, format()을 이용해서 코딩하시오.

name = input('이름을 입력하세요')
birth = input('생년월일을 입력하세요. 예시: 1980/02/09')
age = input('나이를 입력하세요')
month = birth.split('/')[1]

print(" 당신의 이름은 {}이고, {}월 달 출생이고, {}살입니다".format(name, month, age))
# Out:
# 이름을 입력하세요박민호
# 생년월일을 입력하세요. 예시: 1980/02/091980/03/10
# 나이를 입력하세요30
#  당신의 이름은 박민호이고, 03월 달 출생이고, 30살입니다

# %%
url = "http://www.naver.com/news/today=0160831"
log = 'name:홍길동 age:17 sex:남자 nation:대한민국'

# 아래 1, 2와 같이 출력하시오

# 1.
# domain : www.naver.com
# name : 홍길동
# age : 17
# sex : 남자
# nation : 대한민국

# 2.
# 이름은 홍길동이고 나이는 17세, 성별은 남성, 국적은 대한민국입니다..

# %%
val_list = []

for i in log.split(' '):
  # print(i.split(':'))
  key = i.split(':')[0]
  val = i.split(':')[1]
  print(key, ':', val)
  val_list.append(val)
# Out:
# name : 홍길동
# age : 17
# sex : 남자
# nation : 대한민국

# %%
val_list
# Out:
# ['홍길동', '17', '남자', '대한민국']

# %%
text = "이름은 {}이고 나이는 {}세, 성별은 {}, 국적은 {}입니다..".format(val_list[0], val_list[1], val_list[2], val_list[3])
print(text)
# Out:
# 이름은 홍길동이고 나이는 17세, 성별은 남자, 국적은 대한민국입니다..

# %%
# List Quiz

# %%
listdata = [1, 2, 'a', 'b', 'c', [4, 5, 6], '가', '나']
   # 2가 출력됨
   # ‘b’가 출력됨
   # 5가 출력됨
   # 맨 마지막 원소가 추출됨
   # 홀수 번 자리 요소만 추출
   # 5,6을 출력하시오

# %%
sol = ['태양','수성','금성','지구','화성','목성','지구']
sol1 = ['토성','천황성','해왕성']
planet = '지구'

# %%
# 1. sol에서 ['수성','금성']을 출력
# 2. sol에서 '지구' 위치 인덱스 출력
# 3. sol에서 '화성'을 '해왕성'으로 수정
# 4. '수성'자리에 '명왕성' 삽입
# 5. '토성'을 맨 끝에 삽입
# 6. 맨 끝 요소를 삭제하고 리턴
# 7. '금성'을 제거
# 8. 1번 인덱스에서 3번 인덱스까지 삭제
# 9. 인덱스 2번 요소 삭제
# 10. sol과 sol1을 합치세요
# 11. 내림차순 정렬
# 12. 오름차순 정렬
# 13. '만리장성'이 있는지 확인
# 14. so1을 3번 반복하세요
# 15. 길이를 출력하세요
# 16. '지구'가 몇 개 포함되어있는지 확인.
# 17. 모든 원소를 지우세요.
# 18. sol리스트를 삭제하세요..

# %%
# tuple

# %%
t = (1, 2, 3)

# %%
t[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-e6cf7836e708> in <cell line: 1>()
# ----> 1 t[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
t = (1)

# %%
type(t)
# Out:
# int

# %%
t = (1,)

# %%
type(t)
# Out:
# tuple

# %%
t = (1,43,5,3,6,7)

# %%
t[2]
# Out:
# 5

# %%
t[2:3]
# Out:
# (5,)

# %%
len(t)
# Out:
# 6

# %%
sorted(t)
# Out:
# [1, 3, 5, 6, 7, 43]

# %%
# tuple quiz

# %%
myTuple = ("tuple", (1, 2, 3), [4, 5, 6])

# 'tuple'을 출력하시오
# 3을 출력하세요
# 4, 5를 출력하세요
# 4를 출력하세요
# (1, 2, 3)을 출력하세요

myTuple[0]
myTuple[1][2]
myTuple[2][:2]
myTuple[2][0]
myTuple[1]

# %%
my_tuple = (1, 2, 3, 3, 2, 1)
your_tuple = (4, 5, 6)

# 튜플 연산
# our_tuple과 your_tuple을 연결하세요
my_tuple + your_tuple
# mytuple을 3번 반복하세요
my_tuple * 3
# mytuple에 3이 있는지 확인하세요
3 in my_tuple
# mytuple에 5가 있는지 확인하세요
5 in my_tuple
# mytuple에서 1의 갯수를 출력하세요
my_tuple.count(1)
# mytuple에서 index 2자리의 값을 출력하세요
my_tuple[2]

# %%
t_float = (120.09, 9.11, 2.8)

# t_float의 길이를 출력하세요
len(t_float)
# t_float의 최대값을 출력하세요
max(t_float)
# t_float의 최소값을 출력하세요
min(t_float)
# t_float의 합을 출력하세요.
sum(t_float)
# t_float의 평균을 출력하세요.
import numpy as np
np.mean(t_float)

sum(t_float)/len(t_float)

# t_float를 오름차순 정렬하세요
sorted(t_float)

# %%
# set

# %%
l = [12,4,5,3,3,4,5,6]

# %%
s = set(l)
s
# Out:
# {3, 4, 5, 6, 12}

# %%
s.add(100)
s
# Out:
# {3, 4, 5, 6, 12, 100}

# %%
s.remove(100)

# %%
s
# Out:
# {3, 4, 5, 6, 12}

# %%
a = {1,3,5,7}
b = {1,2,4,6,7,8}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
a.intersection(b)
# Out:
# {1, 7}

# %%
a.difference(b)
# Out:
# {3, 5}

# %%
a.symmetric_difference(b)
# Out:
# {2, 3, 4, 5, 6, 8}

# %%
a.isdisjoint(b)
# Out:
# False

# %%
a.issubset(b)
# Out:
# False

# %%
a.issuperset(b)
# Out:
# False

# %%
# set quiz

# %%
# my_set이라는 빈 집합을 만들고 'sky','sea','earth' 세 요소를 추가하시오
my_set = set()

my_set.add('sky')
my_set.add('sea')
my_set.add('earth')

my_set
# Out:
# {'earth', 'sea', 'sky'}

# %%
# ('1', '2')를 추가하시오
# 무작위로 요소 하나를 삭제하시오.

my_set.add(('1','2'))

# %%
s_planet = {'수성','금성','지구','화성','토성','천왕성'}

# '금성'을 삭제하시오
# '해왕성'을 삭제하는 코드를 작성하고, '해왕성'이 없으면  error가 발생하도록 하시오

# s_planet.remove('해왕성')
s_planet.discard("해왕성")

# %%
a = {1,2,3,4,5,6}
b = {1,3,4,7,8,9}

# 두 집합의 합집합을 구하시오
a.union(b)
# 두 집합의 교집합을 구하시오
a.intersection(b)
# 집합 a의 b에 대한 차집합을 구하시오
a.difference(b)
# 대칭차집합을 구하시오
a.sysmetric_difference(b)

c = {5,6}
# a가 c를 포함하는지 확인하시오
a.issuperset(c)
# b가 c를 포함하는지 확인하시오
b.issuperset(c)
# c가 a의 부분집합인지 확인하시오
c.issubset(a)
# c와 b가 서로소인지 확인하시오
c.isdisjoint(b)

# 집합 a의 길이를 구하시오
len(a)
# 집합 b에 7이 포함되어 있는지 확인하시오.
7 in b

# %%
# dictionary

# %%
d = {'one':1, 'two':2, 'three':3}

# %%
d
# Out:
# {'one': 1, 'two': 2, 'three': 3}

# %%
d['two']
# Out:
# 2

# %%
mydict = {}

mydict['math'] = 95
mydict['eng'] = 75
mydict['kor'] = 85

mydict
# Out:
# {'math': 95, 'eng': 75, 'kor': 85}

# %%
mydict['sci'] = 80

# %%
mydict
# Out:
# {'math': 95, 'eng': 75, 'kor': 85, 'sci': 80}

# %%
mydict['eng']= 95
mydict
# Out:
# {'math': 95, 'eng': 95, 'kor': 85, 'sci': 80}

# %%
# 없는 key에 값을 할당하면 원소가 추가
# 있는 key에 값을 할당하면 덮어쓰기..

# %%
mydict
# Out:
# {'math': 95, 'eng': 95, 'kor': 85, 'sci': 80}

# %%
mydict.pop('eng')
mydict
# Out:
# {'math': 95, 'kor': 85, 'sci': 80}

# %%
len(mydict)
# Out:
# 3

# %%
'kor' in mydict
# Out:
# True

# %%
'eng' in mydict
# Out:
# False

# %%
mydict
# Out:
# {'math': 95, 'kor': 85, 'sci': 80}

# %%
mydict['kor']
# Out:
# 85

# %%
mydict['eng']  # error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-33ad9ccff140> in <cell line: 1>()
# ----> 1 mydict['eng']
#
# KeyError: 'eng'

# %%
mydict.get('eng')  # no error

# %%
mydict.get('kor')
# Out:
# 85

# %%
mydict.items()
# Out:
# dict_items([('math', 95), ('kor', 85), ('sci', 80)])

# %%
mydict.keys()
# Out:
# dict_keys(['math', 'kor', 'sci'])

# %%
mydict.values()
# Out:
# dict_values([95, 85, 80])

# %%
mydict
# Out:
# {'math': 95, 'kor': 85, 'sci': 80}

# %%
mydict.setdefault('math')  # 있는 key를 호출하면 값을 출력..
# Out:
# 95

# %%
mydict.setdefault('eng', 100)  # 없는 key를 호출하면 원소가 추가..
# Out:
# 100

# %%
mydict
# Out:
# {'math': 95, 'kor': 85, 'sci': 80, 'eng': 100}

# %%
color = {'red':1, 'blue':3}

# %%
mydict.update(color)

# %%
mydict
# Out:
# {'math': 95, 'kor': 85, 'sci': 80, 'eng': 100, 'red': 1, 'blue': 3}

# %%
# 연속값을 생성하는 함수..

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
list(range(2, 10))
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9]

# %%
list(range(2, 10, 2))
# Out:
# [2, 4, 6, 8]

# %%
# dictionay quiz

# %%
names = {'Mary':10999, 'Sams':2111, 'Aimy':9778, 'Tom':20245,
'Michale':27115, 'Bob':5887, 'Kelly':7855}

# Aimy의 value를 10000으로 수정하세요
names['Aimy'] = 10000
print(names)
# 'Sams'를 삭제하세요
names.pop('Sams')
print(names)
# value 값들의 합을 구하세요
sum(names.values())
# value 값들의 최대값을 구하세요
max(names.values())
# key값들을 출력하세요]
names.keys()
# value값들을 출력하세요
names.values()
# 키는 'Jane', 값은 5688인 요소를 추가하세요..
names['Jane'] = 5688
# name의 key와 valule를 쌍으로 묶어서 출력
names.items()
# 모든 요소를 삭제하세요
names.clear()
# Out:
# {'Mary': 10999, 'Sams': 2111, 'Aimy': 10000, 'Tom': 20245, 'Michale': 27115, 'Bob': 5887, 'Kelly': 7855}
# {'Mary': 10999, 'Aimy': 10000, 'Tom': 20245, 'Michale': 27115, 'Bob': 5887, 'Kelly': 7855}

# %%
names = {'Mary':10999, 'Sams':2111, 'Aimy':9778, 'Tom':20245,
'Michale':27115, 'Bob':5887, 'Kelly':7855}

# names dict의 원소의 수를 출력하시오
len(names)
# names의 key에 Tom이 있는지 확인하시오..
'Tom' in names
# names에서 Jane이 있으면 값을 출력하고, 없으면 0을 출력하시오.
# names['Jane']  -- error
names.get('Jane')  # no error
names.get('Jane', 0)  # 0을 출력..

# names의 값에 5887이 있는지 확인하시오.
5877 in names.values()

# 이름을 입력받은 이름이 names에 있으면 값을 출력하고, 없으면 값 3000으로
#   names에 추가하시오

nam = input('이름을 입력하세요')
names.setdefault(nam, 3000)
# Out:
# 이름을 입력하세요park
# 3000

# %%
names
# Out:
# {'Mary': 10999,
#  'Sams': 2111,
#  'Aimy': 9778,
#  'Tom': 20245,
#  'Michale': 27115,
#  'Bob': 5887,
#  'Kelly': 7855,
#  'park': 3000}

# %%
# dict[key] => value를 출력
# dict[key] => key가 없으면 error

# dict[key] = value => key가 없으면 추가, key가 있으면 value값을 수정

# dict.get(key) => value를 출력
# dict.get(key) => key가 없으면 아무런 변화가 없다
# dict.get(key, k)  => key가 있으면 value를 출력, 없으면 k를 출력

# dict.setdefault(key, value) => key가 있으면 value를 출력, key가 없으면 (key, value)를 추가
